# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(font='IPAGothic')
import statsmodels.api as sm
price=pd.read_csv('pricing.csv',parse_dates=['DATE'])
mark=pd.read_csv('marketing.csv',parse_dates=['DATE'])
tran=pd.read_csv('transaction.csv',parse_dates=['DATE'])

# %%
tran.head(2)# Transaction data
# Out:
#         DATE  USERID  PRICE  UNITS  TOTAL
# 0 2015-04-03    1052    4.0      1    4.0
# 1 2015-04-03    1059    4.0      2    8.0

# %%
price.head(2) # Pricing data
# Out:
#         DATE  PRICE PRICINGPOLICY
# 0 2015-04-03    4.0    LIST PRICE
# 1 2015-04-04    4.0    LIST PRICE

# %%
mark.head(2) # Marketing data
# Out:
#         DATE           MARKETINGEVENT
# 0 2015-04-03          LAUNCH CAMPAIGN
# 1 2015-05-11  MAJOR EVENT SPONSORSHIP

# %%
tran=tran.groupby([ pd.Grouper(key='DATE', freq='D')])['TOTAL'].sum().reset_index()
df=tran
df['PRICE']=price['PRICE'][:len(tran)]
df=df.set_index('DATE')
mark['MARKETINGEVENT'].value_counts()
# Out:
# MINOR EVENT SPONSORSHIP    10
# MAJOR EVENT SPONSORSHIP     8
# MINOR ADVERTISING BUY       6
# MAJOR ADVERTISING BUY       3
# LAUNCH CAMPAIGN             1
# Name: MARKETINGEVENT, dtype: int64

# %%
data = pd.merge(price,mark, on=['DATE'], how='left')
data.fillna(method='ffill', inplace=True)
temp_tran=tran[['DATE','TOTAL']]
data=pd.merge(data,temp_tran, on=['DATE'], how='left')

# %%
dff=data[:len(tran)].set_index('DATE')

# %%
fig = plt.figure(figsize=(15,6))
plt.plot(dff['TOTAL'], color='red')
plt.xlabel('Day', fontsize=10)
plt.ylabel('Total', fontsize=10)
plt.grid()
plt.show()
# Out:
# C:\Users\AJAY\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# findfont: Font family ['IPAGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['IPAGothic'] not found. Falling back to DejaVu Sans.

# %%
res = sm.tsa.seasonal_decompose(np.log(dff.TOTAL.dropna()),freq=7)
fig = res.plot()
fig.set_figheight(8)
fig.set_figwidth(15)
plt.show()
# Out:
# C:\Users\AJAY\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: the 'freq' keyword is deprecated, use 'period' instead
#   """Entry point for launching an IPython kernel.
# findfont: Font family ['IPAGothic'] not found. Falling back to DejaVu Sans.

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(np.log(dff.TOTAL), autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -3.868281604082578
# n_lags: 0.002281082165899693
# p-value: 0.002281082165899693
# Critial Values:
#    1%, -3.445231637930579
# Critial Values:
#    5%, -2.8681012763264233
# Critial Values:
#    10%, -2.5702649212751583

# %%
fig,ax = plt.subplots(2,1,figsize=(20,10))
fig = sm.graphics.tsa.plot_acf(np.log(dff['TOTAL']), lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(np.log(dff['TOTAL']), lags=50, ax=ax[1])
plt.show()

# %%
# feature creation
data=data.set_index('DATE')

# %%
data.PRICE.value_counts()
# Out:
# 4.0    507
# 2.0     28
# 1.0     13
# Name: PRICE, dtype: int64

# %%
def discount(x):
    if x==4:
        return 0
    if x==2:
        return 0.5
    if x==1:
        return 0.75

# %%
data['offer']=data['PRICE'].map(lambda x:1 if x<4 else 0)
data['discount']=data['PRICE'].apply(discount)

# %%
data=data[1:]
data.head()
# Out:
#             PRICE PRICINGPOLICY   MARKETINGEVENT   TOTAL  offer  discount
# DATE
# 2015-04-04    4.0    LIST PRICE  LAUNCH CAMPAIGN  1220.0      0       0.0
# 2015-04-05    4.0    LIST PRICE  LAUNCH CAMPAIGN  1444.0      0       0.0
# 2015-04-06    4.0    LIST PRICE  LAUNCH CAMPAIGN  1652.0      0       0.0
# 2015-04-07    4.0    LIST PRICE  LAUNCH CAMPAIGN  2004.0      0       0.0
# 2015-04-08    4.0    LIST PRICE  LAUNCH CAMPAIGN  2788.0      0       0.0

# %%
#train_test_split
train_start,train_end = '2015-04-04','2016-06-02'
test_start,test_end = '2016-06-03','2016-10-01'
train = data[train_start:train_end]
test = data[test_start:test_end]

# %%
sarimax = sm.tsa.statespace.SARIMAX(np.log(train['TOTAL']),order=(2,0,0),seasonal_order=(0,1,1,7),exog = train[['PRICE','discount','offer']],
                                enforce_stationarity=False, enforce_invertibility=False,freq='D').fit()
sarimax.summary()
# Out:
# C:\Users\AJAY\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               TOTAL   No. Observations:                  426
# Model:             SARIMAX(2, 0, 0)x(0, 1, [1], 7)   Log Likelihood                 430.337
# Date:                             Wed, 13 May 2020   AIC                           -846.674
# Time:                                     07:08:15   BIC                           -818.544
# Sample:                                 04-04-2015   HQIC                          -835.546
#                                       - 06-02-2016
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# PRICE          0.0305      0.011      2.784      0.005       0.009       0.052
# discount      -0.0084      0.003     -3.050      0.002      -0.014      -0.003
# offer          1.5611      0.028     55.628      0.000       1.506       1.616
# ar.L1          0.3564      0.032     11.277      0.000       0.294       0.418
# ar.L2          0.5146      0.026     20.053      0.000       0.464       0.565
# ma.S.L7       -0.9025      0.037    -24.285      0.000      -0.975      -0.830
# sigma2         0.0071      0.000     19.832      0.000       0.006       0.008
# ===================================================================================
# Ljung-Box (Q):                       99.49   Jarque-Bera (JB):               288.62
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.41   Skew:                            -0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.8e+16. Standard errors may be unstable.
# """

# %%
res = sarimax.resid
fig,ax = plt.subplots(2,1,figsize=(15,8))
fig = sm.graphics.tsa.plot_acf(res, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=50, ax=ax[1])
plt.show()

# %%
train.tail()
# Out:
#             PRICE PRICINGPOLICY           MARKETINGEVENT    TOTAL  offer  \
# DATE
# 2016-05-29    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14464.0      0
# 2016-05-30    2.0       50% OFF  MINOR EVENT SPONSORSHIP  78810.0      1
# 2016-05-31    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  13908.0      0
# 2016-06-01    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14504.0      0
# 2016-06-02    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  18068.0      0
#
#             discount
# DATE
# 2016-05-29       0.0
# 2016-05-30       0.5
# 2016-05-31       0.0
# 2016-06-01       0.0
# 2016-06-02       0.0

# %%
## Full training data prediction

# %%
from sklearn.metrics import mean_squared_error
pred = sarimax.predict('2015-04-04','2016-06-02',exog = train[['PRICE','discount','offer']])
# print('SARIMAX model MSE:{}'.format(mean_squared_error(test['TOTAL'],np.exp(pred))))

# %%
pd.DataFrame({'test':train['TOTAL'][-300:],'pred':np.exp(pred)[-300:]}).plot(figsize=(10,6),alpha=0.8)
plt.show()

# %%
test.head(30)
# Out:
#             PRICE PRICINGPOLICY           MARKETINGEVENT    TOTAL  offer  \
# DATE
# 2016-06-03    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17840.0      0
# 2016-06-04    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17328.0      0
# 2016-06-05    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14496.0      0
# 2016-06-06    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  13756.0      0
# 2016-06-07    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14284.0      0
# 2016-06-08    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14492.0      0
# 2016-06-09    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17332.0      0
# 2016-06-10    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  18104.0      0
# 2016-06-11    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17404.0      0
# 2016-06-12    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14908.0      0
# 2016-06-13    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  13768.0      0
# 2016-06-14    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  13428.0      0
# 2016-06-15    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  15040.0      0
# 2016-06-16    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17524.0      0
# 2016-06-17    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17728.0      0
# 2016-06-18    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17104.0      0
# 2016-06-19    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14924.0      0
# 2016-06-20    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  13700.0      0
# 2016-06-21    2.0       50% OFF  MINOR EVENT SPONSORSHIP  75518.0      1
# 2016-06-22    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14820.0      0
# 2016-06-23    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  16700.0      0
# 2016-06-24    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17856.0      0
# 2016-06-25    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17456.0      0
# 2016-06-26    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14560.0      0
# 2016-06-27    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  13532.0      0
# 2016-06-28    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  13584.0      0
# 2016-06-29    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  14136.0      0
# 2016-06-30    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17020.0      0
# 2016-07-01    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  17320.0      0
# 2016-07-02    4.0    LIST PRICE  MINOR EVENT SPONSORSHIP  16412.0      0
#
#             discount
# DATE
# 2016-06-03       0.0
# 2016-06-04       0.0
# 2016-06-05       0.0
# 2016-06-06       0.0
# 2016-06-07       0.0
# 2016-06-08       0.0
# 2016-06-09       0.0
# 2016-06-10       0.0
# 2016-06-11       0.0
# 2016-06-12       0.0
# 2016-06-13       0.0
# 2016-06-14       0.0
# 2016-06-15       0.0
# 2016-06-16       0.0
# 2016-06-17       0.0
# 2016-06-18       0.0
# 2016-06-19       0.0
# 2016-06-20       0.0
# 2016-06-21       0.5
# 2016-06-22       0.0
# 2016-06-23       0.0
# 2016-06-24       0.0
# 2016-06-25       0.0
# 2016-06-26       0.0
# 2016-06-27       0.0
# 2016-06-28       0.0
# 2016-06-29       0.0
# 2016-06-30       0.0
# 2016-07-01       0.0
# 2016-07-02       0.0

# %%
## Test data prediction and comparision
from sklearn.metrics import mean_squared_error
pred_test = sarimax.predict('2016-06-03','2016-07-02',exog = test[['PRICE','discount','offer']][:30])
print('SARIMAX model MSE:{}'.format(mean_squared_error(test['TOTAL'][:30],np.exp(pred_test))))
# Out:
# SARIMAX model MSE:7903383.778365234

# %%
pd.DataFrame({'test':test['TOTAL'][:30],'pred':np.exp(pred_test)}).plot(figsize=(10,6),alpha=0.5)
plt.show()

# %%
## Out of Sample prediction for 3 month upto 1/10/2016

pred_out = sarimax.predict('2016-06-03','2016-10-01',exog = test[['PRICE','discount','offer']])
pd.DataFrame({'test':test['TOTAL'],'pred':np.exp(pred_out)}).plot(figsize=(12,6),alpha=0.5)
plt.show()

# %%
# sarimax.plot_diagnostics(figsize=(15, 6))

# %%
# weeklty prediction
test1=test[:30]
test1['sx_total_pred']=np.exp(pred_test)
week_act=pd.DataFrame()
week_pred=pd.DataFrame()
week_act['ACTUAL_TOTAL']=test1['TOTAL']
week_pred['PRED_TOTAL']=test1['sx_total_pred']
week_act=week_act.reset_index() 
week_pred=week_pred.reset_index()
week_act=week_act.groupby([ pd.Grouper(key='DATE', freq='W-SAT')])['ACTUAL_TOTAL'].sum().reset_index()
week_pred=week_pred.groupby([ pd.Grouper(key='DATE', freq='W-SAT')])['PRED_TOTAL'].sum().reset_index()
week_act['PRED_TOTAL']=week_pred['PRED_TOTAL']
week_act.set_index('DATE').plot(figsize=(12,6))
plt.title("WEEKLY  REVENUE FORECASTED")
plt.show()
# Out:
# C:\Users\AJAY\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
## Out of sample Forecasting for next 3 months

# %%
np.exp(pred_out).plot(figsize=(15,6))
data.TOTAL.plot(figsize=(15,6),alpha=0.5)

# %%
## Writing csv file of out of sample forecast

# %%
ps_1=test
ps_1=ps_1['2016-07-03':]
ps_1['Predicted_Revenue']=np.exp(pred_out)
ps_1=ps_1.reset_index()
weekly_revenue=ps_1.groupby([ pd.Grouper(key='DATE', freq='W-SAT')])['Predicted_Revenue'].sum().reset_index()
# Out:
# C:\Users\AJAY\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ps_1.head(7).Predicted_Revenue.sum()
# Out:
# 105919.51866319377

# %%
sol_1=pd.read_csv('problem-one-sample-answer.csv',header=None)
sol_1[2]=weekly_revenue['Predicted_Revenue']
sol_1.to_csv('problem-one-answer.csv',header=False,index=False)

# %%
############################################################END#################################################################
